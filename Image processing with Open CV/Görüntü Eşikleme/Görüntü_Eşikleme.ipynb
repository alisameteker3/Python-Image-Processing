# %%
import cv2
import numpy as np
import matplotlib.pylab as plt

# %%
img = cv2.imread("./agac.jfif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY )
plt.figure()
plt.imshow(img , cmap = "gray")
plt.axis("off")
plt.show()

# %%
#piksel değerleri 'thresh' verilen değerden büyükse arkayı beyaza çeviriri 
#piksel değerleri 'thresh' verilen değerden küçükse arkayı siyaha çevirir
_, thresh_img = cv2.threshold(img, thresh= 60, maxval = 255, type = cv2.THRESH_BINARY)

# %%
plt.figure()
plt.imshow(img , cmap = "gray")
plt.axis("off")
plt.title("orginal img")
plt.show()

plt.figure()
plt.imshow(thresh_img , cmap = "gray")
plt.axis("off")
plt.title("BINARY img")
plt.show()

# %%
_,thresh_img_ınv = cv2.threshold(img, thresh = 60 , maxval= 255, type = cv2.THRESH_BINARY_INV)

# %%
plt.figure()
plt.imshow(thresh_img_ınv, cmap="gray")
plt.axis("off")
plt.show()

# %%
thresh_img2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,115,8)

# %%
plt.figure()
plt.imshow(thresh_img2 , cmap = "gray")
plt.axis = "off"
plt.show()
